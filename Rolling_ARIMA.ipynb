# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans
from pyspark.sql.functions import *
from datetime import datetime
from pyspark.sql.functions import to_date, to_timestamp

import requests, pandas as pd, numpy as np
from pandas import DataFrame
from io import StringIO
import time, json
from datetime import date
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
import matplotlib.pylab as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
confirmed_cases = spark.table("g6_confirmed_cases_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
confirmed_cases_pandas = confirmed_cases.toPandas()
confirmed_cases_pandas['Date'] = pd.to_datetime(confirmed_cases_pandas['Date'], infer_datetime_format = True)
confirmed_cases_init = confirmed_cases_pandas.set_index('Date')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#canada_cases = confirmed_cases[["Date", "canada_cases"]]
canada_final = confirmed_cases_init[["canada_cases"]]
#japan_cases = confirmed_cases[["Date", "japan_cases"]]
japan_final = confirmed_cases_init[["japan_cases"]]
#italy_cases = confirmed_cases[["Date", "italy_cases"]]
italy_final = confirmed_cases_init[["italy_cases"]]
#uk_cases = confirmed_cases[["Date", "uk_cases"]]
uk_final = confirmed_cases_init[["uk_cases"]]
#germany_cases = confirmed_cases[["Date", "germany_cases"]]
germany_final = confirmed_cases_init[["germany_cases"]]
#france_cases = confirmed_cases[["Date", "france_cases"]]
france_final = confirmed_cases_init[["france_cases"]]

japan_final["japan_cases"] = japan_final["japan_cases"].replace(0, 1)

italy_final["italy_cases"] = italy_final["italy_cases"].replace(0, 1)

uk_final["uk_cases"] = uk_final["uk_cases"].replace(0, 1)

#germany_final["germany_cases"] = germany_final["germany_cases"].replace(0, 1)

france_final["france_cases"] = france_final["france_cases"].replace(0, 1)

ts_jap_log = np.log(japan_final)

ts_ita_log = np.log(italy_final)

ts_uk_log = np.log(uk_final)

ts_fra_log = np.log(france_final)

#ts_log['canada_cases'] = ts_log['canada_cases'].diff()
ts_jap_log['japan_cases'] = ts_jap_log['japan_cases'].diff()
ts_ita_log['italy_cases'] = ts_ita_log['italy_cases'].diff()
ts_uk_log['uk_cases'] = ts_uk_log['uk_cases'].diff()
#ts_ger_log['germany_cases'] = ts_ger_log['germany_cases'].diff()
ts_fra_log['france_cases'] = ts_fra_log['france_cases'].diff()

#ts_log['canada_cases'] = ts_log['canada_cases'].fillna(0)
ts_jap_log['japan_cases'] = ts_jap_log['japan_cases'].fillna(0)
ts_ita_log['italy_cases'] = ts_ita_log['italy_cases'].fillna(0)
ts_uk_log['uk_cases'] = ts_uk_log['uk_cases'].diff().fillna(0)
#ts_ger_log['germany_cases'] = ts_ger_log['germany_cases'].fillna(0)
ts_fra_log['france_cases'] = ts_fra_log['france_cases'].fillna(0)

can_diff = canada_final
#jap_diff = japan_final
#ita_diff = italy_final
#uk_diff = uk_final
#ger_diff = germany_final
#fra_diff = france_final

can_diff['canada_cases'] = can_diff['canada_cases'].diff()
#jap_diff['japan_cases'] = jap_diff['japan_cases'].diff()
#ita_diff['italy_cases'] = ita_diff['italy_cases'].diff()
#uk_diff['uk_cases'] = uk_diff['uk_cases'].diff()
#ger_diff['germany_cases'] = ger_diff['germany_cases'].diff()
#fra_diff['france_cases'] = fra_diff['france_cases'].diff()

can_diff['canada_cases'] = can_diff['canada_cases'].fillna(0)

can_diff.drop(can_diff.index[0], inplace=True)

ts_jap_log.drop(ts_jap_log.index[0], inplace=True)

ts_ita_log.drop(ts_ita_log.index[0], inplace=True)

ts_uk_log.drop(ts_uk_log.index[0], inplace=True)

germany_final.drop(germany_final.index[0], inplace=True)

ts_fra_log.drop(ts_fra_log.index[0], inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1597764241098-0/PythonShell.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import time
# /local_disk0/tmp/1597764241098-0/PythonShell.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /local_disk0/tmp/1597764241098-0/PythonShell.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from six import StringIO  # cString does not support unicode well
# /local_disk0/tmp/1597764241098-0/PythonShell.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /local_disk0/tmp/1597764241098-0/PythonShell.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from pyspark.conf import SparkConf
# /local_disk0/tmp/1597764241098-0/PythonShell.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from databricksCli import init_databricks_cli_config_provider
# /databricks/python/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# </div>

# %% [markdown]
# # 14 days (Canada)

# %%
model_test = ARIMA(can_diff.iloc[88:102].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[88:102])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[:88], 'blue', label='training data') 
ax.plot(can_diff.iloc[88:102], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %%
model_test = ARIMA(can_diff.iloc[102:116].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[102:116])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[14:102], 'blue', label='training data') 
ax.plot(can_diff.iloc[102:116], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %% [markdown]
# # 7 days (Canada)

# %%
model_test = ARIMA(can_diff.iloc[88:95].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[88:95])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[:88], 'blue', label='training data') 
ax.plot(can_diff.iloc[88:95], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %%
model_test = ARIMA(can_diff.iloc[95:102].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[95:102])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[7:95], 'blue', label='training data') 
ax.plot(can_diff.iloc[95:102], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %%
model_test = ARIMA(can_diff.iloc[102:109].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[102:109])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[14:102], 'blue', label='training data') 
ax.plot(can_diff.iloc[102:109], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %%
model_test = ARIMA(can_diff.iloc[109:116].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[109:116])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[21:109], 'blue', label='training data') 
ax.plot(can_diff.iloc[109:116], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)

# %% [markdown]
# # 1 day (Canada)

# %%
model_test = ARIMA(can_diff.iloc[88:89].astype(float), order=(0, 1, 1)) 
results_test_ARIMA = model_test.fit(maxiter=500) 

fitted_values_test  = results_test_ARIMA.predict(1,len(can_diff.iloc[88:89])-1,typ='linear') 
fitted_values_test_frame = fitted_values_test.to_frame()

fig, ax = plt.subplots(figsize=(20,5))
ax.set(title='Predictions', xlabel='Date', ylabel='Total Number of Cases')
ax.plot(can_diff.iloc[:88], 'blue', label='training data') 
ax.plot(can_diff.iloc[88:89], 'black', label='test data actuals')
ax.plot(fitted_values_test_frame, 'r', label='test data forecast')  # np.exp(predictions_series)
legend = ax.legend(loc='upper left')
legend.get_frame().set_facecolor('w')
display(fig.figure)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-494943876683888&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>model_test <span class="ansi-blue-fg">=</span> ARIMA<span class="ansi-blue-fg">(</span>can_diff<span class="ansi-blue-fg">.</span>iloc<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">88</span><span class="ansi-blue-fg">:</span><span class="ansi-cyan-fg">90</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>astype<span class="ansi-blue-fg">(</span>float<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> order<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> results_test_ARIMA <span class="ansi-blue-fg">=</span> model_test<span class="ansi-blue-fg">.</span>fit<span class="ansi-blue-fg">(</span>maxiter<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">500</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> fitted_values_test  <span class="ansi-blue-fg">=</span> results_test_ARIMA<span class="ansi-blue-fg">.</span>predict<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span>len<span class="ansi-blue-fg">(</span>can_diff<span class="ansi-blue-fg">.</span>iloc<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">88</span><span class="ansi-blue-fg">:</span><span class="ansi-cyan-fg">90</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">-</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span>typ<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;linear&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> fitted_values_test_frame <span class="ansi-blue-fg">=</span> fitted_values_test<span class="ansi-blue-fg">.</span>to_frame<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py</span> in <span class="ansi-cyan-fg">__new__</span><span class="ansi-blue-fg">(cls, endog, order, exog, dates, freq, missing)</span>
# <span class="ansi-green-intense-fg ansi-bold">    994</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    995</span>             mod <span class="ansi-blue-fg">=</span> super<span class="ansi-blue-fg">(</span>ARIMA<span class="ansi-blue-fg">,</span> cls<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>__new__<span class="ansi-blue-fg">(</span>cls<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 996</span><span class="ansi-red-fg">             </span>mod<span class="ansi-blue-fg">.</span>__init__<span class="ansi-blue-fg">(</span>endog<span class="ansi-blue-fg">,</span> order<span class="ansi-blue-fg">,</span> exog<span class="ansi-blue-fg">,</span> dates<span class="ansi-blue-fg">,</span> freq<span class="ansi-blue-fg">,</span> missing<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    997</span>             <span class="ansi-green-fg">return</span> mod
# <span class="ansi-green-intense-fg ansi-bold">    998</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py</span> in <span class="ansi-cyan-fg">__init__</span><span class="ansi-blue-fg">(self, endog, order, exog, dates, freq, missing)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1018</span>         self<span class="ansi-blue-fg">.</span>endog <span class="ansi-blue-fg">=</span> np<span class="ansi-blue-fg">.</span>diff<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>endog<span class="ansi-blue-fg">,</span> n<span class="ansi-blue-fg">=</span>d<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1019</span>         <span class="ansi-red-fg">#NOTE: will check in ARMA but check again since differenced now</span>
# <span class="ansi-green-fg">-&gt; 1020</span><span class="ansi-red-fg">         </span>_check_estimable<span class="ansi-blue-fg">(</span>len<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>endog<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> p<span class="ansi-blue-fg">+</span>q<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1021</span>         <span class="ansi-green-fg">if</span> exog <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1022</span>             self<span class="ansi-blue-fg">.</span>exog <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>exog<span class="ansi-blue-fg">[</span>d<span class="ansi-blue-fg">:</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py</span> in <span class="ansi-cyan-fg">_check_estimable</span><span class="ansi-blue-fg">(nobs, n_params)</span>
# <span class="ansi-green-intense-fg ansi-bold">    421</span> <span class="ansi-green-fg">def</span> _check_estimable<span class="ansi-blue-fg">(</span>nobs<span class="ansi-blue-fg">,</span> n_params<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    422</span>     <span class="ansi-green-fg">if</span> nobs <span class="ansi-blue-fg">&lt;=</span> n_params<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 423</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> ValueError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Insufficient degrees of freedom to estimate&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    424</span>
# <span class="ansi-green-intense-fg ansi-bold">    425</span>
#
# <span class="ansi-red-fg">ValueError</span>: Insufficient degrees of freedom to estimate</div>
